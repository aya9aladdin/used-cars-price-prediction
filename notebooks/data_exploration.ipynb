# %%
import findspark
findspark.init()
from pyspark import SparkConf
from pyspark.sql import SparkSession

# %% [markdown]
# # Begin Pyspark session

# %%
spark = SparkSession.builder \
    .appName("Redshift Connection with PySpark") \
    .config("spark.jars", "redshift-jdbc42-2.1.0.20.jar") \
    .getOrCreate()

conf = SparkConf()
conf.set("spark.driver.maxResultSize", "2g")

redshift_url ="jdbc:redshift://cars-cluster.c7utbjvxgyyz.eu-north-1.redshift.amazonaws.com:5439/cars"

redshift_properties = {
    "user": "aya",
    "password": "***",
    "driver": "com.amazon.redshift.Driver"
}

cars_query = "(SELECT cars.*, classes.model, classes.brand, classes.class, body.body FROM cars.prod.cars_data as cars join cars.prod.cars_classes_data as classes on cars.class_id = classes.class_id join cars.prod.cars_body_data as body on classes.model = body.model and classes.brand = body.brand)"

car_df = spark.read.jdbc(redshift_url, cars_query,
                         properties=redshift_properties)


car_df = car_df.repartition(1000)  # Adjust the number of partitions as needed
# Out:
# 23/11/06 19:54:03 WARN Utils: Your hostname, Aya-MacBook.local resolves to a loopback address: 127.0.0.1; using 192.168.1.3 instead (on interface en0)
# 23/11/06 19:54:03 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 23/11/06 19:54:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/11/06 19:54:17 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %% [markdown]
# ## Explore columns

# %%
car_df.columns
# Out:
# ['car_id',
#  'class_id',
#  'model_year',
#  'ad_date',
#  'transmission',
#  'price',
#  'fingerprint',
#  'km',
#  'color',
#  'fuel',
#  'city',
#  'model',
#  'brand',
#  'class',
#  'body']

# %%
car_df.groupBy('brand', 'model').count().orderBy('model').show()
# Out:
# [Stage 11:==================================================>  (949 + 8) / 1000]
# +-------+-----+-----+
# |  brand|model|count|
# +-------+-----+-----+
# |   Audi|  100|    1|
# |Renault|   11|    1|
# |   Fiat| 1100|    7|
# |    BMW|  116|   15|
# |    BMW|  118|    5|
# |Renault|   12|    1|
# | Datsun|  120|    1|
# |    BMW|  120|    2|
# |   Lada| 1200|    4|
# |  Mazda|  121|    5|
# |   Lada|  124|    1|
# |   Fiat|  124|    6|
# |   Fiat|  125|    4|
# |   Fiat|  126|    1|
# |   Fiat|  127|   67|
# |   Fiat|  128|  253|
# |   Lada| 1300|    4|
# |   Fiat| 1300|    2|
# |   Seat|  131|    2|
# |   Fiat|  131|   65|
# +-------+-----+-----+
# only showing top 20 rows

# %% [markdown]
#  we can see that model name solely is not unique and can be found for more than one brand

# %%
car_df.groupBy('city').count().orderBy('count').show()
# Out:
# [Stage 17:===================================================> (977 + 8) / 1000]
# +--------------------+-----+
# |                city|count|
# +--------------------+-----+
# |      Ras al Khaimah|    1|
# |          El-Alamein|    2|
# |            El Gouna|    3|
# |                Edku|    5|
# |New Administrativ...|    6|
# |          Ras Gharib|    7|
# |          Kafr Shukr|    7|
# |              Safaga|    7|
# |            Kom Ombo|    8|
# |         El Gamaleya|   14|
# |             Rosetta|   19|
# |          Abu Hummus|   20|
# |            El-Arish|   25|
# |                Tala|   27|
# |              Amreya|   28|
# |       Marsa Matrouh|   28|
# |    El Wadi El Gedid|   29|
# |              Menouf|   32|
# |             Zamalek|   34|
# |           El Bagour|   39|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# we can see that some city representation is rare... we can group cities by governorate to get better overview of cars demography

# %%
car_df.groupBy('class').count().orderBy('count', ascending=False).show(500)
# Out:
# [Stage 29:==============================================>      (884 + 8) / 1000]
# +--------------------+-----+
# |               class|count|
# +--------------------+-----+
# |                    |21269|
# |                None|10118|
# |              Manual|  229|
# |            Automtic|  103|
# |                 M/T|   54|
# |Automatic / High ...|   52|
# |           Automatic|   41|
# |Automatic / High ...|   40|
# |Automtic / Tinted...|   36|
# |        Manual / A/C|   36|
# |    luxury automatic|   31|
# |Automatic / Tinte...|   25|
# |           A/T GL HD|   24|
# |full option / Aut...|   23|
# |   Automatic / Turbo|   22|
# |           M/T / F/O|   22|
# |ِAutomatic / Limited|   22|
# | Automatic / Dynamic|   18|
# |             F/O M/T|   16|
# |Automatic / full ...|   16|
# |Automatic / Pure ...|   15|
# |  Automatic / LUXURY|   15|
# |Automatic / full ...|   15|
# |             manual‏|   15|
# |        A/T / Luxury|   13|
# |Manual / Tinted G...|   12|
# |Automatic / VTI /...|   12|
# |        A/T / Active|   12|
# |Automatic / full ...|   11|
# |       1.6 A/T Sport|   11|
# |            A/T / B2|   11|
# |           HB A/T EX|   11|
# |      A/T / Highline|   10|
# |                 A/T|   10|
# |Automatic / full ...|   10|
# |           A/T / GLX|   10|
# |Manual / full option|    9|
# |    Manual / A/C New|    9|
# |     A/T / COUPE AMG|    9|
# |   A/T / PROGRESSIVE|    8|
# |   Automatic / TURBO|    8|
# |  1.6 A/T Avantgarde|    8|
# |A/T / xDrive30i x...|    8|
# |ِِAutomatic / GL CVT|    8|
# |Automatic / full ...|    8|
# |    A/T / 450 4MATIC|    7|
# |HIGHLINE / full o...|    7|
# |A/T / Coupe Progr...|    7|
# |       A/T / Comfort|    7|
# |         A/T / Style|    6|
# |           A/T / LXI|    6|
# |   A/T / Luxury Line|    6|
# |full option / Aut...|    6|
# |     A/T / Exclusive|    5|
# |Automatic / full ...|    5|
# |      A/T / Ambition|    5|
# |    A/T / Gran Coupe|    5|
# |           A/T / AMG|    5|
# | Automatic / M Sport|    5|
# |        A/T / S-Line|    5|
# |full option / Aut...|    5|
# |        A/T / R-Line|    4|
# |       M/T / TOPLINE|    4|
# |         A/T / Sport|    4|
# |   A/T / Full option|    4|
# |       A/T / Premium|    4|
# |      A/T / Elegance|    4|
# |             Manual‏|    4|
# |Automatic / VTI H...|    4|
# |        A/T / SW NAG|    4|
# |      F/O A/ S Turbo|    4|
# |    2016 full option|    3|
# |   Automatic / Sport|    3|
# |Automatic / Full ...|    3|
# |            A/T / LX|    3|
# |       A/T Urban 200|    3|
# |            A/T / GT|    3|
# |   Automatic / Urban|    3|
# |         A/T / Vison|    3|
# |Automatic Special...|    3|
# |  Automatic / Luxury|    3|
# |     A/T / EXCLUSIVE|    3|
# |Automatic / Exclu...|    3|
# |            A/T / L1|    3|
# |    A/T / Sport Line|    3|
# |  A/T / Full Options|    3|
# |      A/T / Top Line|    3|
# |  Automatiic / Urban|    3|
# |A/T / GT pack Red...|    3|
# |A/T / 200 Progres...|    3|
# |       F/O M/T basic|    3|
# |     A/T / 580 class|    3|
# |      A/T / Standard|    3|
# |   A/T / COMFORTLINE|    3|
# |  Automatic / Active|    2|
# |         A/T / SMART|    2|
# |     Automatic / AMG|    2|
# | A/T / SPORTS TOURER|    2|
# |Automatic / Flagship|    2|
# |      A/T / Two tone|    2|
# | Automatic / Elgance|    2|
# |      A/T / One tone|    2|
# |A/T / DAB ABS TIN...|    2|
# |         A/T / Turbo|    2|
# |            A/T / B1|    2|
# |Automatic / Exclu...|    2|
# |Manual / Full opt...|    2|
# |A/T / P250 R Dynamic|    2|
# |             A/T AMG|    2|
# | Automatic / Comfort|    2|
# |      A/T GL H/L H/D|    2|
# |            A/T / SE|    2|
# |          A/T / M50I|    2|
# |A/T / Performance...|    2|
# |Automatic / full ...|    2|
# |full option / Aut...|    2|
# |Automatic / GLS /...|    2|
# |       Automtic / LS|    2|
# |        A/T / Allure|    2|
# |A/T / GT Red inte...|    2|
# |    Manual / Elegent|    2|
# |Automatic / GLS /...|    2|
# |Automatic / Avant...|    2|
# |manual‏ / Power S...|    2|
# |   1.6 A/T F/O Sedan|    2|
# |A/T / Full Option...|    2|
# |         M/T Classic|    2|
# |Automatic / High ...|    2|
# |         Manual / GL|    2|
# |Manual / GLS New ...|    2|
# |Automatic / TURBO...|    2|
# |       A/T / PREMIUM|    2|
# |            A/T / FR|    2|
# |     AT-6DCT COMFORT|    2|
# |       A/T / Dynamic|    2|
# |     1.6 A/T Premium|    2|
# |Automatic / full ...|    2|
# |    A/T / SPORT LINE|    2|
# |        A/T / Access|    2|
# |      A/T / Trend 4d|    2|
# |A/T / Pure Excell...|    2|
# |      GL / Automatic|    2|
# |         A/T Titanim|    2|
# |  A/T / CONV.M SPORT|    2|
# |      A/T / Advanced|    2|
# |    Automatic / Base|    2|
# |  Automtic / Stander|    2|
# |            A/T / SW|    2|
# |    A/T Coupe Luxury|    2|
# |           A/T / L&K|    2|
# |    A/T / Experience|    2|
# |A/T / Limited Pan...|    2|
# |   Automatic / Trend|    2|
# |A/T / ADVANCED / ...|    2|
# |     A/T / AMG Coupe|    1|
# |             M/T STD|    1|
# |Automatic /T5 Pol...|    1|
# |    A/T / Avantgarde|    1|
# |Automatic / Sport...|    1|
# |A/T / Avantgarde ...|    1|
# |AT / Dynamic / Turbo|    1|
# |Automatic / High ...|    1|
# |          1.6 A/T EX|    1|
# |      manual‏ / long|    1|
# |Automtic / GLS / ...|    1|
# |         A/T / VISIA|    1|
# |            A/T / H1|    1|
# |     A/T H/L NAV F/L|    1|
# |        A/T Top line|    1|
# |Automatic / Trend...|    1|
# |            A/T / E2|    1|
# | A/T / M Performance|    1|
# |full option / Aut...|    1|
# |Automatic / Activ...|    1|
# |Manual / GLS Tint...|    1|
# |           A/T sport|    1|
# |          A/T Vision|    1|
# |     manual‏ / salon|    1|
# |  A/T F/O HB 5 Doors|    1|
# |Automatic Luxury 4WD|    1|
# |             A/T GLS|    1|
# |A/T / DAB ABS PLU...|    1|
# |Automatic / Turbo...|    1|
# |             F/O A/T|    1|
# |Automatic / GLS /...|    1|
# |     Automatic / GLS|    1|
# |Manual / Full Option|    1|
# |   Automatic / Style|    1|
# |   A/T / Inspire GLS|    1|
# |       A/T / GT-Line|    1|
# |   Automatic GT Line|    1|
# |          A/T / Feel|    1|
# |      A/T / Titanium|    1|
# |      A/T / ADVANCED|    1|
# |full option / aut...|    1|
# |Automtic / GLX MI...|    1|
# |   A/T / Inscription|    1|
# |A/T / Signature /...|    1|
# |Automatic / Execu...|    1|
# |      Automtic / HSE|    1|
# |Automatic / full ...|    1|
# |Automatic / full ...|    1|
# |    Automatic / LIVE|    1|
# |    Manual / TOPLINE|    1|
# |    A/T / GL DAB ABS|    1|
# |M/T GL (Tinted glass|    1|
# |Automatic / GT Li...|    1|
# |              manual|    1|
# |     A/T / H/L Opera|    1|
# |Automatic / GLS /...|    1|
# |    Automtic / Visia|    1|
# |Automatic H/B SKY...|    1|
# |Automatic / Allur...|    1|
# |           A/T / 500|    1|
# |full option / manual|    1|
# |Automatic / Turbo...|    1|
# |          A/T / LX-S|    1|
# |      Automatic Base|    1|
# |Automatic / GLS /...|    1|
# |       A/T / Classic|    1|
# |Automatic / Sport...|    1|
# |Automatic / GT Li...|    1|
# |Automatic / Panorama|    1|
# |          A/T / Base|    1|
# |        f/o a/t 1600|    1|
# |        A/T / Veloce|    1|
# |      A/T / Momentum|    1|
# |A/T GL DAB ABS HD...|    1|
# | Automatic / GT Line|    1|
# |Automatic / full ...|    1|
# |     Automatic / HSE|    1|
# |Automatic / Trend...|    1|
# |Automatic / M-per...|    1|
# |Automatic / M-Spo...|    1|
# |       A/T / GT Line|    1|
# |full option / Aut...|    1|
# |        A/T / Design|    1|
# |      A/T / Utlimate|    1|
# |     A/T / Signature|    1|
# |       Manual / Base|    1|
# |A/T / S-Line w Ne...|    1|
# |M/T GL (Tinted gl...|    1|
# |            A/T / EX|    1|
# |Automatic / Business|    1|
# |      A/T / P300 HSE|    1|
# |              A/T EX|    1|
# |       A/T Exclusive|    1|
# |Automatic / High ...|    1|
# |    A/T / Sport plus|    1|
# |        M/T Highline|    1|
# |        A/T / screen|    1|
# |            A/T 3600|    1|
# |A/T / sport / whi...|    1|
# |A/T / Performance...|    1|
# |        Automatic BL|    1|
# |Automatic / full ...|    1|
# |   Automatic / coupe|    1|
# |       A/T Face Lift|    1|
# |     A/T / SW Screen|    1|
# |   Automatic / Basic|    1|
# |  A/T / TINTED GLASS|    1|
# |Automtic / Acenta...|    1|
# |        A/T / ACTIVE|    1|
# |   AT / GL / TOPLINE|    1|
# |    A/T / Smart Plus|    1|
# |A/T / GT Line Lim...|    1|
# |  Automatic / access|    1|
# |       Automtic / RS|    1|
# |Manual /Double Ca...|    1|
# |  Manual / Base Line|    1|
# |Automatic / Top Line|    1|
# |  Automatic / X Line|    1|
# |manual / / High l...|    1|
# |        A/T / Super+|    1|
# |manual‏ / Full op...|    1|
# |     A/T / Advantage|    1|
# |Automatic / Turbo LS|    1|
# |   A/T / Sport - RED|    1|
# |  AT / GL / HIGHLINE|    1|
# |Automatic / full ...|    1|
# |         A/T / STYLE|    1|
# |   Automatic / Royal|    1|
# |           A/T Coupe|    1|
# |      A/T / Allure +|    1|
# |Automatic / Activ...|    1|
# | Automatic / Midline|    1|
# | 1.6 A/T SAB S/R H/L|    1|
# |full option / Aut...|    1|
# |Automatic / SW / ...|    1|
# |GLS (Tinted glass...|    1|
# |Manual / Double C...|    1|
# |A/T / Sportline p...|    1|
# |      EX F/O A/T 1.6|    1|
# | Automatic / LT Plus|    1|
# |A/T / AMG A35 4M ...|    1|
# |   Automatic / turbo|    1|
# |    Automatic / Easy|    1|
# |Automatic / full ...|    1|
# |               A/T /|    1|
# |            MT/ HIGH|    1|
# |         A/T / Smart|    1|
# |Automatic / High ...|    1|
# |    A/T / STYLE PLUS|    1|
# |    A/T / Super Plus|    1|
# |             A/T F/O|    1|
# |         A/T / Elite|    1|
# |      A/T / Core FWD|    1|
# |  manual‏ / Baseline|    1|
# |      A/T / top line|    1|
# |Automatic / A/T A...|    1|
# |A/T / PREMIUM / W...|    1|
# |Automatic / Full ...|    1|
# |           A/T Sport|    1|
# |    F/O A/T / HB 1.5|    1|
# |Automatic / HB / ...|    1|
# |Automatic / full ...|    1|
# |     A/T / Xcellence|    1|
# |        A/T / SPIRIT|    1|
# |Automatic / GL/ S...|    1|
# | A/T / sport designo|    1|
# |     A/T HSE Dynamic|    1|
# |           A/T / 4X4|    1|
# |    Automtic / Tekna|    1|
# |A/T / Active Pack...|    1|
# |ِAutomatic / top ...|    1|
# |Automatic / 5 Sea...|    1|
# |  A/T / Salt Edition|    1|
# |   manual / Standard|    1|
# |A/T / Feel with s...|    1|
# |     Automatic / F/O|    1|
# |Automtic / Trendl...|    1|
# |A/T / High Lne / ...|    1|
# |Automatic / Highl...|    1|
# |          A/T / M50i|    1|
# |Automatic / sport...|    1|
# |     Automatic Trend|    1|
# |Automatic / GT Li...|    1|
# |              A/T LX|    1|
# |Automatic / Smart...|    1|
# |Automatic / Gdi 7...|    1|
# |      A/T / Ultimate|    1|
# |    A/T / SMART PLUS|    1|
# |         A/T / Opera|    1|
# |    A/T / HB E3 T GT|    1|
# |   Automatic GLS T/L|    1|
# |Automatic / Refer...|    1|
# |Automatic / Cabri...|    1|
# |    Automatic / Feel|    1|
# |           SW H/L LX|    1|
# |A/T / FSI quattro...|    1|
# |        A/T / Deluxe|    1|
# |Automatic / Coupe...|    1|
# |             A/T GLX|    1|
# |  A/T / Sport Shadow|    1|
# |   A/T / Allure Pack|    1|
# |        Automatic cc|    1|
# |1.6 A/T Urban H/L...|    1|
# |    A/T / Premium SV|    1|
# |         A/T / Shine|    1|
# |ِِAutomatic / Luxury|    1|
# |A/T / FEEL / with...|    1|
# |GL 2.0 4WD / full...|    1|
# |A/T / GT Red inte...|    1|
# | Automatic H/B Trend|    1|
# |Automatic / full ...|    1|
# |          ِAutomatic|    1|
# |      Automatic / BL|    1|
# |            MT‏ / L1|    1|
# |Automatic / full ...|    1|
# |Automatic / Turbo LT|    1|
# |     Automatic / H/L|    1|
# |Automatic / full ...|    1|
# |Automatic / full ...|    1|
# |        Manual / H/O|    1|
# |     F/O A/T comfort|    1|
# |   A/T / S Line Plus|    1|
# |Automatic / Elega...|    1|
# |Automatic / GL / ...|    1|
# |       A/T / Intense|    1|
# |       1.6 HB A/T HL|    1|
# |A/T / Inscription...|    1|
# |Automatic / M - S...|    1|
# |       A/T / Topline|    1|
# |Automtic / GLS FU...|    1|
# |AT / BASELINE Lea...|    1|
# |            A/T / L2|    1|
# |       A/T / INTENSE|    1|
# |   A/T / Limited 4WD|    1|
# |Automatic / SPORT...|    1|
# |Manual / Base Lin...|    1|
# |Automatic / Elega...|    1|
# |A/T / SR TINTED G...|    1|
# |A/T F/O (Baseline...|    1|
# |     A/T / AMG Coupé|    1|
# |         A/T F/O H/B|    1|
# |A/T / P300 R Dynamic|    1|
# |    Automatic / 1.6L|    1|
# |A/T / P300 R Dyna...|    1|
# |A/T / S /Chili Ed...|    1|
# |  Automtic / TOPLINE|    1|
# |       Automtic / GR|    1|
# |AT / HIGHLINE two...|    1|
# |         A/T fashion|    1|
# |full option / Aut...|    1|
# |      A/T Trend Plus|    1|
# |    Automatic GLS ML|    1|
# |   Automatic 1.6 H/L|    1|
# |      A/T / AMBITION|    1|
# |Automatic / Turbo...|    1|
# |Automatic / Turbo...|    1|
# |         AMG N/A A/T|    1|
# |A/T / AMG A35 4M ...|    1|
# |      A/T / R-Design|    1|
# |      Automatic / LX|    1|
# |   A/T / (350) coupe|    1|
# |A/T / Highline / ...|    1|
# |          A/T / Live|    1|
# |Automtic / red in...|    1|
# |GL A/T H/L H/B Ex...|    1|
# | Automatic / Premium|    1|
# |A/T / Line Gran C...|    1|
# |             A/T H/L|    1|
# |      Automatic / GL|    1|
# | Automatic / Limited|    1|
# |     M/T Classic Van|    1|
# |A/T / Signature T...|    1|
# |Automatic / Activ...|    1|
# |Automatic / full ...|    1|
# |A/T / SMART PLUS ...|    1|
# |Automatic / full ...|    1|
# |     A/T / ADVANTAGE|    1|
# |    M/T F/O Panorama|    1|
# |      A/T Style Plus|    1|
# |Automatic / Limit...|    1|
# |Automatic / P250 ...|    1|
# |     hiline a/t 1600|    1|
# |A/T / HighLine Li...|    1|
# |   Automatic / sport|    1|
# |     A/T / Executive|    1|
# |Automatic / H/P / FR|    1|
# |            A/T / E1|    1|
# |Automatic / SMART...|    1|
# |      A/T Avantgarde|    1|
# |     A/T / high line|    1|
# |        A/T / Shadow|    1|
# |   A/T / Instyle GLS|    1|
# |A/T / Highline / ...|    1|
# |   A/T / Luxury Plus|    1|
# |A/T / LUX / Red I...|    1|
# |Automtic / GLS PL...|    1|
# |         Manual / E2|    1|
# |    A/T / AVANTGARDE|    1|
# |       HB F/O H/L FL|    1|
# |   Manual / Baseline|    1|
# |Automatic / Turbo P2|    1|
# |            M/T Easy|    1|
# |SR GLS Fully Load...|    1|
# |    A/T / sport line|    1|
# |       Automatic H/L|    1|
# |            A/T / VX|    1|
# |         AT / Spirit|    1|
# |       A/T / GT pack|    1|
# |A/T / High Line /...|    1|
# |     Automatic / 2WD|    1|
# +--------------------+-----+

# %% [markdown]
# Most cars are either basic or have no class, so we can put all of those in one category. Some classes are just indication to the car transmission type (automatic or manual). We can remove this data as theere is already a transmission column in the data.

# %%
car_df.groupBy('body').count().orderBy('count', ascending=False).show()
# Out:
# [Stage 35:============================================>        (844 + 8) / 1000]
# +------------+-----+
# |        body|count|
# +------------+-----+
# |       sedan|22255|
# |         SUV| 5983|
# |   hatchback| 3408|
# |         4X4|  959|
# |pickup truck|  192|
# |       coupe|  125|
# |   mini Vans|  111|
# |     Minivan|   23|
# |       truck|   17|
# |       Sedan|   16|
# |      sports|    4|
# |         Van|    2|
# |  sports car|    1|
# +------------+-----+
